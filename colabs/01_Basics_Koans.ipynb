# %% [markdown]
# # 🥋 Python Basics Koans
# **Goal:** Master variables, types, strings, and booleans.
# **Rule:** Fix the `TODO`s to pass the assertions.

# %% [markdown]
# ## 1. Variables & Assignment
# Python variables are dynamic. Fix the assignment to make the assertions pass.
#
# ### Key Concepts:
# * Variables can change types even after assignment.
# * Python uses a colon (`:`) to open blocks such as functions and conditionals.
# * The equals sign (`=`) stores the right-hand value into the left-hand name.
#
# Concepts: `01-syntax.md`

# %%
def variable_assignment():
    # TODO: Assign the integer 10 to x
    x = None
    
    # TODO: Assign the string "Hello" to y
    y = None
    
    # TODO: Assign True to z
    z = None
    
    return x, y, z

# %%
# 🧪 TEST BLOCK
try:
    x, y, z = variable_assignment()
    assert x == 10, f"Expected 10, got {x}"
    assert y == "Hello", f"Expected 'Hello', got {y}"
    assert z is True, f"Expected True, got {z}"
    print("✅ Variables Passed!")
except Exception as e:
    print(f"❌ Failed: {e}")

# %% [markdown]
# ## 2. String Manipulation
# Use string methods `upper()`, `lower()`, and string slicing.
#
# ### Key Concepts:
# * Strings are ordered sequences that support slicing and indexing.
# * Methods like `.upper()` and `.lower()` transform the case.
# * f-strings (`f"{value}"`) let you embed expressions directly in text.
#
# Concepts: `04-strings.md`

# %%
def string_mastery(text):
    # text is "Python Programming"
    
    # TODO: Convert to uppercase
    upper_text = ""
    
    # TODO: Convert to lowercase
    lower_text = ""
    
    # TODO: Slice to get just "Python" (first 6 chars)
    sliced_text = ""
    
    return upper_text, lower_text, sliced_text

# %%
# 🧪 TEST BLOCK
try:
    u, l, s = string_mastery("Python Programming")
    assert u == "PYTHON PROGRAMMING"
    assert l == "python programming"
    assert s == "Python"
    print("✅ Strings Passed!")
except Exception as e:
    print(f"❌ Failed: {e}")

# %% [markdown]
# ## 3. Booleans & Types
# Check types and boolean logic.
#
# ### Key Concepts:
# * Boolean expressions evaluate to `True` or `False` and drive `if` statements.
# * Use `type()` to inspect the kind of object you are working with.
# * Combine comparisons with `and` / `or` to guard logic paths.
#
# Concepts: `03-types.md`

# %%
def boolean_logic(age, has_id):
    # TODO: Return True if age >= 18 AND has_id is True
    can_enter = False
    
    # TODO: Check if age is an integer using isinstance
    is_age_int = False
    
    return can_enter, is_age_int

# %%
# 🧪 TEST BLOCK
try:
    assert boolean_logic(20, True) == (True, True)
    assert boolean_logic(17, True) == (False, True)
    assert boolean_logic(20, False) == (False, True)
    print("✅ Booleans Passed!")
except Exception as e:
    print(f"❌ Failed: {e}")
