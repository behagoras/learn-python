# %% [markdown]
# # 🥋 Python Basics Koans
# **Goal:** Master variables, types, strings, and booleans.
# **Rule:** Fix the `TODO`s to pass the assertions.

# %% [markdown]
# ## 🛠️ Setup & Utilities
# Run this cell to load the test validation helper functions.

# %%
# 🛠️ UTILITY: Accepts a tuple (Actual, Expected) as the first argument
def validate_test_case(test_pair, error_template, error_list):
    actual_result, expected_value = test_pair 
    if actual_result != expected_value:
        msg = error_template.format(actual=actual_result, expected=expected_value)
        error_list.append(f"❌ {msg}")

def log_errors(errors):
    if errors:
        for err in errors:
            print(err)
    else:
        print("✅ All Tests Passed!")

# %% [markdown]
# ## 1. Variables & Assignment
#
# Python variables are dynamic labels for values.
#
# ### Key Concepts:
# * **Dynamic Typing**: You don't need to declare types (e.g., `x = 10`).
# * **Syntax**: Variable names are case-sensitive.
# * **Blocks**: Python uses colons (`:`) and indentation to define blocks of code (like in functions or loops).
#
# 🔗 Concepts: `01-intro.md`
#
# **Task:** Fix the assignment to make the assertions pass.

# %%
def variable_assignment():
    # TODO: Assign the integer 10 to x
    x = None
    
    # TODO: Assign the string "Hello" to y
    y = None
    
    # TODO: Assign True to z
    z = None
    
    return x, y, z

# %%
# 🧪 TEST BLOCK
errors = []
x, y, z = variable_assignment()

validate_test_case((x, 10), "Expected 10, got {actual}", errors)
validate_test_case((y, "Hello"), "Expected 'Hello', got {actual}", errors)
validate_test_case((z, True), "Expected True, got {actual}", errors)

log_errors(errors)
# Out:
# ✅ All Tests Passed!

# %% [markdown]
# ## 2. String Manipulation
#
# Strings are sequences of characters.
#
# ### Key Concepts:
# * **Methods**: `upper()`, `lower()`, `replace()`.
# * **Slicing**: Extract parts of string `text[start:end]`.
# * **f-strings**: Embed variables directly: `f"Hello {name}"`.
#
# 🔗 Concepts: `04-strings.md`
#
# **Task:** Use string methods `upper()`, `lower()`, and string slicing.

# %%
def string_mastery(text):
    # text is "Python Programming"
    
    # TODO: Convert to uppercase
    upper_text = ""
    
    # TODO: Convert to lowercase
    lower_text = ""
    
    # TODO: Slice to get just "Python" (first 6 chars)
    sliced_text = ""
    
    return upper_text, lower_text, sliced_text

# %%
# 🧪 TEST BLOCK
errors = []
u, l, s = string_mastery("Python Programming")

validate_test_case((u, "PYTHON PROGRAMMING"), "Upper failed: {actual}", errors)
validate_test_case((l, "python programming"), "Lower failed: {actual}", errors)
validate_test_case((s, "Python"), "Slice failed: {actual}", errors)

log_errors(errors)
# Out:
# ✅ All Tests Passed!

# %% [markdown]
# ## 3. Booleans & Types
#
# Logic dictates the flow of your program.
#
# ### Key Concepts:
# * **Booleans**: `True` or `False`.
# * **Comparisons**: `==`, `!=`, `>`, `<`.
# * **Type Checking**: Use `type(x)` to see what x is, or `isinstance(x, int)` to check.
#
# 🔗 Concepts: `10-operadores-logicos.md`
#
# **Task:** Check types and boolean logic.

# %%
def boolean_logic(age, has_id):
    # TODO: Return True if age >= 18 AND has_id is True
    can_enter = False
    
    # TODO: Check if age is an integer using isinstance
    is_age_int = False
    
    return can_enter, is_age_int

# %%
# 🧪 TEST BLOCK
errors = []

validate_test_case((boolean_logic(20, True), (True, True)), "Failed for (20, True)", errors)
validate_test_case((boolean_logic(17, True), (False, True)), "Failed for (17, True)", errors)
validate_test_case((boolean_logic(20, False), (False, True)), "Failed for (20, False)", errors)

log_errors(errors)
# Out:
# ✅ All Tests Passed!
