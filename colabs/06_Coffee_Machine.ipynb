# %% [markdown]
# # ☕ Coffee Machine Koans
# **Goal:** Build a complete coffee ordering system using Functions, Logic, and File I/O.

# %% [markdown]
# ## 🛠️ Setup & Utilities
# Run this cell to load the test validation helper functions.

# %%
# 🛠️ UTILITY
def validate_test_case(test_pair, error_template, error_list):
    actual_result, expected_value = test_pair 
    if actual_result != expected_value:
        msg = error_template.format(actual=actual_result, expected=expected_value)
        error_list.append(f"❌ {msg}")

def log_errors(errors):
    if errors:
        for err in errors:
            print(err)
    else:
        print("✅ All Tests Passed!")

# %% [markdown]
# ## 1. Menu Module
#
# First, we need to display what we serve.
#
# ### Key Concepts:
# * **Modular Design**: Breaking a big problem into small functions.
# * **Print Formatting**: Presenting data clearly.
#
# 🔗 Concepts: `31-maquina-cafe.md`
#
# **Task:** Create a `show_menu()` function that returns the menu as a formatted string.

# %%
def show_menu():
    # TODO: Return a multi-line string with the menu options:
    # 1. Espresso
    # 2. Cappuccino
    # 3. Latte
    return ""

# %%
# 🧪 TEST BLOCK
errors = []
menu_text = show_menu()
validate_test_case(("Espresso" in menu_text, True), "Menu should contain Espresso", errors)
log_errors(errors)

# %% [markdown]
# ## 2. Order Processing
#
# We need to translate user input (numbers) into coffee names.
#
# ### Key Concepts:
# * **Dictionaries**: Ideal for mapping options to values.
# * **Input Validation**: Handling invalid choices.
#
# **Task:** Create `order_coffee(choice)` that returns the coffee name or None.

# %%
def order_coffee(choice):
    menu = {
        "1": "Espresso",
        "2": "Cappuccino",
        "3": "Latte"
    }
    # TODO: Return the value from menu if choice exists
    # TODO: Return None if not found
    return menu.get(choice)

# %%
# 🧪 TEST BLOCK
errors = []
validate_test_case((order_coffee("1"), "Espresso"), "Expected Espresso, got {actual}", errors)
validate_test_case((order_coffee("9"), None), "Expected None, got {actual}", errors)
log_errors(errors)

# %% [markdown]
# ## 3. File Persistence
#
# We want to save every order to a file.
#
# ### Key Concepts:
# * **Append Mode ('a')**: Adds to the file without erasing it.
# * **Encoding**: `utf-8` ensures emoji/special char compatibility.
#
# **Task:** Save the order to `orders.txt`.

# %%
def save_order(order_text):
    # TODO: Open 'orders.txt' in append mode
    # TODO: Write the order_text plus a newline
    pass

# %% [markdown]
# ## 4. History Reader
#
# Read back previous orders.
#
# ### Key Concepts:
# * **Error Handling**: Handle if the file doesn't exist yet.
# * **Enumeration**: Numbering the lines.
#
# **Task:** Return a list of all past orders.

# %%
def view_history():
    history = []
    # TODO: Try to open orders.txt in read mode
    # TODO: Read lines and strip whitespace
    # TODO: Handle FileNotFoundError by returning empty list
    return history

# %% [markdown]
# ## 5. Main Loop Integration
#
# Combine everything into a running app.
#
# ### Key Concepts:
# * **While True**: Infinite loop for the menu.
# * **Break**: Exit condition.
#
# **Task:** Complete the main application loop.

# %%
def main_app():
    print("☕ Welcome to the Cafe!")
    while True:
        print(show_menu())
        print("4. History")
        print("5. Exit")
        
        choice = input("Select: ")
        
        if choice == "5":
            print("Goodbye!")
            break
            
        elif choice == "4":
            print("--- History ---")
            # TODO: Call view_history() and print each item
            
        else:
            # TODO: Call order_coffee(choice)
            # TODO: If valid, print serving message and call save_order()
            pass

# To run: main_app()
